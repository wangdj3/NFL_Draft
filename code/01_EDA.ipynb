# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df2022 = pd.read_csv('../data/2022_combine.csv')
df2022.head()
# Out:
#               Player   Pos      School    Ht   Wt  40yd  Vertical  Bench  \
# 0       Cal Adomitis    LS  Pittsburgh   6-2  235  4.97      29.5   18.0
# 1       Austin Allen    TE    Nebraska   6-8  253  4.83      34.0    NaN
# 2        Chase Allen    TE    Iowa St.   6-6  251   NaN      33.5    NaN
# 3  Christopher Allen  EDGE     Alabama   6-4  241   NaN       NaN    NaN
# 4     Tyler Allgeier    RB         BYU  5-11  224  4.60      33.0    NaN
#
#    Broad Jump  3Cone  Shuttle
# 0       107.0   7.53     4.62
# 1       121.0   7.00     4.26
# 2       117.0   7.03     4.43
# 3         NaN    NaN      NaN
# 4       120.0    NaN      NaN

# %%
df2022['Player'].nunique()
# Out:
# 324

# %%
df2022.shape
# Out:
# (324, 11)

# %%
college_qbr = pd.read_csv('../data/college_qbr.csv')
college_qbr.head()
# Out:
#    season                              guid     player_name   age  total_qbr  \
# 0    2004  b518c8332d8a45a6348f93e245d3aca8   Stefan LeFors  23.0       86.3
# 1    2004  5cb521dc4af2c7598251a369ffaf4c72      Alex Smith  36.0       84.5
# 2    2004  00be888b38b5e26fc4b4d18aca23e7b7     Jason White  24.0       84.1
# 3    2004  c794b72ed323e01f9bc984d5a48003ff  Jason Campbell  33.0       83.3
# 4    2004  a7277955dbfa7b56283b8246d4ba987c      Matt Jones  32.0       81.7
#
#    points_added  qb_plays  total_epa  pass   run  exp_sack  penalty  raw_qbr  \
# 0          68.3       351       66.8  66.5   2.8      -3.7      1.6     88.3
# 1          75.8       480       73.4  63.5  16.0      -7.3      1.2     83.8
# 2          56.6       454       61.2  70.9  -6.2      -5.4      2.7     78.5
# 3          41.5       373       48.4  56.9  -3.9      -6.5      2.0     76.1
# 4          35.9       383       43.6  24.4  27.5      -7.1     -0.7     72.6
#
#    sack
# 0  -3.7
# 1  -7.3
# 2  -6.1
# ...

# %%
college_statistics = pd.read_csv('../data/college_statistics.csv')
college_statistics.head()
# Out:
#    player_id  alt_player_id  player_name pos_abbr   school school_abbr  \
# 0      14420        3915189  Royce Smith       OG  Georgia         UGA
# 1      14420        3915189  Royce Smith       OG  Georgia         UGA
# 2      14420        3915189  Royce Smith       OG  Georgia         UGA
# 3      14420        3915189  Royce Smith       OG  Georgia         UGA
# 4      14420        3915189  Royce Smith       OG  Georgia         UGA
#
#   school_primary_color school_alt_color  season        statistic  value  \
# 0              #CC0000          #000000    2015    Total Tackles   20.0
# 1              #CC0000          #000000    2015     Solo Tackles    9.0
# 2              #CC0000          #000000    2015   Assist Tackles   11.0
# 3              #CC0000          #000000    2015  Passes Defended    0.0
# 4              #CC0000          #000000    2015            Sacks    0.0
#
#    active  all_star
# 0    True     False
# 1    True     False
# 2    True     False
# ...

# %%
nfl_draft_profiles = pd.read_csv('../data/nfl_draft_profiles.csv')
nfl_draft_profiles.head()
# Out:
#    player_id guid  alt_player_id     player_name       position pos_abbr  \
# 0      23590  NaN            NaN     Bubba Smith  Defensive End       DE
# 1      23591  NaN            NaN   Clinton Jones   Running Back       RB
# 2      23592  NaN            NaN  Steve Spurrier    Quarterback       QB
# 3      23593  NaN            NaN      Bob Griese    Quarterback       QB
# 4      23594  NaN            NaN  George Webster     Linebacker       LB
#
#    weight  height player_image  \
# 0       0     0.0          NaN
# 1       0     0.0          NaN
# 2       0     0.0          NaN
# 3       0     0.0          NaN
# 4       0     0.0          NaN
#
#                                                 link  ...          school  \
# 0  http://insider.espn.com/nfl/draft/player/_/id/...  ...  Michigan State
# 1  http://insider.espn.com/nfl/draft/player/_/id/...  ...  Michigan State
# 2  http://insider.espn.com/nfl/draft/player/_/id/...  ...         Florida
# ...

# %%
nfl_draft_profiles.columns
# Out:
# Index(['player_id', 'guid', 'alt_player_id', 'player_name', 'position',
#        'pos_abbr', 'weight', 'height', 'player_image', 'link', 'school_logo',
#        'school', 'school_abbr', 'school_name', 'pos_rk', 'ovr_rk', 'grade',
#        'text1', 'text2', 'text3', 'text4'],
#       dtype='object')

# %%
nfl_draft_prospects = pd.read_csv('../data/nfl_draft_prospects.csv')
nfl_draft_prospects.head()
# Out:
#    draft_year  player_id     player_name       position pos_abbr  \
# 0        1967      23590     Bubba Smith  Defensive End       DE
# 1        1967      23591   Clinton Jones   Running Back       RB
# 2        1967      23592  Steve Spurrier    Quarterback       QB
# 3        1967      23593      Bob Griese    Quarterback       QB
# 4        1967      23594  George Webster     Linebacker       LB
#
#            school   school_name school_abbr  \
# 0  Michigan State      Spartans         MSU
# 1  Michigan State      Spartans         MSU
# 2         Florida        Gators         FLA
# 3          Purdue  Boilermakers         PUR
# 4  Michigan State      Spartans         MSU
#
#                                                 link  pick  ...  \
# 0  http://insider.espn.com/nfl/draft/player/_/id/...   1.0  ...
# 1  http://insider.espn.com/nfl/draft/player/_/id/...   2.0  ...
# 2  http://insider.espn.com/nfl/draft/player/_/id/...   3.0  ...
# ...

# %%
#Since we only have (easily available) combine data from year 2000+, let's just discard all data older than that.
nfl_draft_prospects = nfl_draft_prospects[nfl_draft_prospects['draft_year']>=2000]

# %%
nfl_draft_prospects[nfl_draft_prospects['overall']==1].tail()
# Out:
#        draft_year  player_id      player_name       position pos_abbr  \
# 11493        2017      51534    Myles Garrett  Defensive End       DE
# 11862        2018     101525   Baker Mayfield    Quarterback       QB
# 12241        2019     103832     Kyler Murray    Quarterback       QB
# 12641        2020     104204       Joe Burrow    Quarterback       QB
# 12988        2021     104734  Trevor Lawrence    Quarterback       QB
#
#           school school_name school_abbr  \
# 11493  Texas A&M      Aggies        TA&M
# 11862   Oklahoma     Sooners        OKLA
# 12241   Oklahoma     Sooners        OKLA
# 12641        LSU      Tigers         LSU
# 12988    Clemson      Tigers        CLEM
#
#                                                     link  pick  ...  \
# 11493  http://insider.espn.com/nfl/draft/player/_/id/...   1.0  ...
# 11862  http://insider.espn.com/nfl/draft/player/_/id/...   1.0  ...
# 12241  http://insider.espn.com/nfl/draft/player/_/id/...   1.0  ...
# ...

# %%
nfl_draft_profiles[nfl_draft_profiles['player_id']==104734]
# Out:
#        player_id                              guid  alt_player_id  \
# 12539     104734  76111495d1d92333170d4206eebe673f      4360310.0
#
#            player_name     position pos_abbr  weight  height  \
# 12539  Trevor Lawrence  Quarterback       QB     213  77.625
#
#                                             player_image  \
# 12539  https://a.espncdn.com/i/headshots/nfldraft/pla...
#
#                                                     link  ...   school  \
# 12539  http://insider.espn.com/nfl/draft/player/_/id/...  ...  Clemson
#
#       school_abbr school_name pos_rk  ovr_rk  grade  \
# 12539        CLEM      Tigers    1.0     1.0   97.0
#
#                                                    text1  \
# 12539  Lawrence is a tall, well-built quarterback who...
#
#                                                    text2  \
# 12539  Lawrence is a sound decision-maker and natural...
#
#                                                    text3 text4
# ...

# %%
college_statistics[college_statistics['player_id']==104734].head()
# Out:
#        player_id  alt_player_id      player_name pos_abbr   school  \
# 50994     104734        4360310  Trevor Lawrence       QB  Clemson
# 50995     104734        4360310  Trevor Lawrence       QB  Clemson
# 50996     104734        4360310  Trevor Lawrence       QB  Clemson
# 50997     104734        4360310  Trevor Lawrence       QB  Clemson
# 50998     104734        4360310  Trevor Lawrence       QB  Clemson
#
#       school_abbr school_primary_color school_alt_color  season  \
# 50994        CLEM              #F66733          #522d80    2018
# 50995        CLEM              #F66733          #522d80    2018
# 50996        CLEM              #F66733          #522d80    2018
# 50997        CLEM              #F66733          #522d80    2018
# 50998        CLEM              #F66733          #522d80    2018
#
#                     statistic   value  active  all_star
# 50994             Completions   259.0    True     False
# 50995        Passing Attempts   397.0    True     False
# ...

# %%
college_statistics['season'].value_counts()
# Out:
# 2017    15739
# 2018    15283
# 2016    12241
# 2019    10208
# 2015     7120
# 2020     3416
# 2014     2665
# Name: season, dtype: int64
